# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

# %% [markdown]
# # PTEN
# * i think they used `Imputed_Score` as their mutational tolerance score

# %%
# header is in row 2
pten_data = pd.read_excel("mmc2.xlsx", sheet_name="Table S2", skiprows=[0]) 
pten_data
# Out:
# c:\Users\liyoa\anaconda3\envs\sbna\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
#      Variant (one letter) Variant (three letter)   Change Wt_codon Mut_codon  \
# 0                     M1A                Met1Ala  A (Ala)      ATG       GCT
# 1                     M1V                Met1Val  V (Val)      ATG       GTT
# 2                     M1I                Met1Ile  I (Ile)      ATG       ATT
# 3                     M1L                Met1Leu  L (Leu)      ATG       TTG
# 4                     M1M                Met1Met  M (Met)      ATG       ATG
# ...                   ...                    ...      ...      ...       ...
# 8861                V403K              Val403Lys  K (Lys)      GTC       AAA
# 8862                V403D              Val403Asp  D (Asp)      GTC       GAT
# 8863                V403E              Val403Glu  E (Glu)      GTC       GAA
# ...

# %%
# plot boxplot of Cum_score

ax = sns.boxplot(x=pten_data[pten_data['Type']=="missense"]["Imputed_Score"])
plt.show()
